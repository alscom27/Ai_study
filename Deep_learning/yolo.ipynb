# %% [markdown]
# yolov8n

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# 저장된 모델 불로오기 
model = YOLO('yolov8n.pt')

# 예측할 미디어 경로 설정
image_path = './imgs/man_car_cat.jpg'

# 이미지 예측
results_image = model.predict(source=image_path, save=True, show=True)
print(f'이미지 예측 결과 : {results_image}')
# Out:
# WARNING Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\main\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 68.1MB/s]
# image 1/1 c:\Users\main\workspace\ai_class\Deep_learning\imgs\man_car_cat.jpg: 640x480 20 persons, 10 cars, 1 cat, 5 dogs, 7 chairs, 2 potted plants, 1 dining table, 71.7ms
# Speed: 5.9ms preprocess, 71.7ms inference, 172.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs\detect\predict
# 이미지 예측 결과 : [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
print(type(model.names), len(model.names))
print(model.names)
# Out:
# <class 'dict'> 80
# ...

# %%
import cv2
from ultralytics import YOLO # YOLOv8 라이브러리
# 1. YOLO 모델 불러오기 (사전학습된 모델 사용)
model = YOLO('yolov8n.pt') # 경량화 모델로 빠르게 확인 가능
# 2. 웹캠 열기 (기본 카메라 index=0)
cap = cv2.VideoCapture(0)
# 3. 반복적으로 프레임 읽고 객체 감지
while True:
    ret, frame = cap.read()
    if not ret:
        break

    # 4. YOLO 예측
    results = model(frame, show=False, stream=True) # stream=True: 실시간 감지

    # 5. 결과 프레임 출력
    for result in results:
        annotated_frame = result.plot() # 예측결과로 이미지 그리기
        cv2.imshow('YOLOv8 Real-time Detection', annotated_frame)

    # 6. 종료 조건 (q 키를 누르면 종료)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# 7. 자원 해제
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 2 persons, 1 chair, 4.8ms
# Speed: 1.5ms preprocess, 4.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 5.5ms
# Speed: 1.5ms preprocess, 5.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 6.0ms
# Speed: 1.6ms preprocess, 6.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 8.7ms
# Speed: 1.3ms preprocess, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 4.7ms
# Speed: 1.5ms preprocess, 4.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# ...

# %% [markdown]
# fire and smoke segmentation

# %%
import torch
print(torch.cuda.is_available())  # True면 GPU 사용 가능
print(torch.cuda.get_device_name(0))  # 그래픽카드 이름
# Out:
# True
# NVIDIA GeForce RTX 3070 Ti Laptop GPU

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ElIox72mujQ8VOYKZdPN")
project = rf.workspace("roboflow-universe-projects").project("fire-and-smoke-segmentation")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Fire-and-Smoke-Segmentation-6 in yolov8:: 100%|██████████| 14232/14232 [00:08<00:00, 1747.08it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # or yolov8s.pt / custom .pt

model.train(
    data="./Fire-and-Smoke-Segmentation-6/data.yaml",  # roboflow에서 받은 yaml
    epochs=10,
    imgsz=640,
    batch=16,
    device=0  # ✅ GPU 사용 (0: 첫 번째 GPU)
)
# Out:
# Ultralytics 8.3.146  Python-3.12.9 torch-2.7.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")  # or yolov8s.pt / custom .pt

model.train(
    data="./Fire-and-Smoke-Segmentation-6/data.yaml",  # roboflow에서 받은 yaml
    epochs=10,
    imgsz=640,
    batch=16,
    device=0  # ✅ GPU 사용 (0: 첫 번째 GPU)
)
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 83.4MB/s]
# Ultralytics 8.3.146  Python-3.12.9 torch-2.7.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# ...

# %%
from ultralytics import YOLO
import cv2

# best.pt 모델 로드
# model = YOLO('/runs/detect/train2/weights/best.pt') # 경로를 본인의 best.pt로 수정!
model = YOLO('C:/Users/main/workspace/ai_class/Deep_learning/runs/detect/train2/weights/best.pt')
# 예측할 이미지 경로
image_path = './imgs/naroho_cut.png' # 예측할 이미지 경로
# 예측 수행
results = model.predict(
 source=image_path, # 이미지 파일 경로 (또는 폴더 경로, 비디오 경로, 0: 웹캠)
 save=True, # 예측 결과 이미지 저장
show=True, # 팝업 창에 결과 출력
conf=0.5, # 탐지 신뢰도 threshold 0.5 -> 0.3
 device=0, # GPU: 0 / CPU: 'cpu'
 # 추가
 iou=0.7,
 agnostic_nms=True,
 max_det=100
)
# 결과 확인
for result in results:
    print(result.boxes) # 감지된 객체의 경계 상자 정보
    cv2.waitKey(0)
 
cv2.destroyAllWindows()
# Out:
# image 1/1 c:\Users\main\workspace\ai_class\Deep_learning\imgs\naroho_cut.png: 384x640 (no detections), 28.7ms
# Speed: 2.7ms preprocess, 28.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict9
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([], device='cuda:0')
# conf: tensor([], device='cuda:0')
# data: tensor([], device='cuda:0', size=(0, 6))
# id: None
# is_track: False
# orig_shape: (261, 457)
# shape: torch.Size([0, 6])
# xywh: tensor([], device='cuda:0', size=(0, 4))
# xywhn: tensor([], device='cuda:0', size=(0, 4))
# xyxy: tensor([], device='cuda:0', size=(0, 4))
# xyxyn: tensor([], device='cuda:0', size=(0, 4))

# %%
from ultralytics import YOLO
import cv2

# best.pt 모델 로드
# model = YOLO('/runs/detect/train2/weights/best.pt') # 경로를 본인의 best.pt로 수정!
model = YOLO('C:/Users/main/workspace/ai_class/Deep_learning/runs/detect/train3/weights/best.pt')
# 예측할 이미지 경로
image_path = './imgs/fire_smoke2.jpg' # 예측할 이미지 경로
# 예측 수행
results = model.predict(
 source=image_path, # 이미지 파일 경로 (또는 폴더 경로, 비디오 경로, 0: 웹캠)
 save=True, # 예측 결과 이미지 저장
show=True, # 팝업 창에 결과 출력
conf=0.5, # 탐지 신뢰도 threshold 0.5 -> 0.3
 device=0, # GPU: 0 / CPU: 'cpu'
 # 추가
 iou=0.7,
 agnostic_nms=True,
 max_det=100
)
# 결과 확인
for result in results:
    print(result.boxes) # 감지된 객체의 경계 상자 정보
    cv2.waitKey(0)
 
cv2.destroyAllWindows()
# Out:
# image 1/1 c:\Users\main\workspace\ai_class\Deep_learning\imgs\fire_smoke2.jpg: 448x640 2 fires, 41.6ms
# Speed: 2.6ms preprocess, 41.6ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs\detect\predict10
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 0.], device='cuda:0')
# conf: tensor([0.8301, 0.6929], device='cuda:0')
# data: tensor([[ 41.1169,  94.9907, 100.2189, 182.6213,   0.8301,   0.0000],
#         [138.2353,  90.3964, 243.7719, 182.9586,   0.6929,   0.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (183, 275)
# shape: torch.Size([2, 6])
# xywh: tensor([[ 70.6679, 138.8060,  59.1020,  87.6306],
#         [191.0036, 136.6775, 105.5366,  92.5622]], device='cuda:0')
# xywhn: tensor([[0.2570, 0.7585, 0.2149, 0.4789],
#         [0.6946, 0.7469, 0.3838, 0.5058]], device='cuda:0')
# xyxy: tensor([[ 41.1169,  94.9907, 100.2189, 182.6213],
# ...

# %%
from PIL import Image
img = Image.open("runs/detect/train2/results.png")
img.show()

# %%
from PIL import Image
img = Image.open("runs/detect/train3/results.png")
img.show()

# %%
from ultralytics import YOLO

model = YOLO("yolov8n-seg.pt")  # or yolov8s.pt / custom .pt

model.train(
    data="./Fire-and-Smoke-Segmentation-6/data.yaml",  # roboflow에서 받은 yaml
    epochs=10,
    imgsz=640,
    batch=16,
    device=0  # ✅ GPU 사용 (0: 첫 번째 GPU)
)
# Out:
# ...
# 100%|██████████| 6.74M/6.74M [00:00<00:00, 80.4MB/s]
# Ultralytics 8.3.146  Python-3.12.9 torch-2.7.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# ...

# %%
from ultralytics import YOLO
import cv2

# best.pt 모델 로드
# model = YOLO('/runs/detect/train2/weights/best.pt') # 경로를 본인의 best.pt로 수정!
model = YOLO('C:/Users/main/workspace/ai_class/Deep_learning/runs/segment/train/weights/best.pt')
# 예측할 이미지 경로
image_path = './imgs/fire_smoke2.jpg' # 예측할 이미지 경로
# 예측 수행
results = model.predict(
 source=image_path, # 이미지 파일 경로 (또는 폴더 경로, 비디오 경로, 0: 웹캠)
 save=True, # 예측 결과 이미지 저장
show=True, # 팝업 창에 결과 출력
conf=0.5, # 탐지 신뢰도 threshold 0.5 -> 0.3
 device=0, # GPU: 0 / CPU: 'cpu'
 # 추가
 iou=0.7,
 agnostic_nms=True,
 max_det=100
)
# 결과 확인
for result in results:
    print(result.boxes) # 감지된 객체의 경계 상자 정보
    cv2.waitKey(0)
 
cv2.destroyAllWindows()
# Out:
# image 1/1 c:\Users\main\workspace\ai_class\Deep_learning\imgs\fire_smoke2.jpg: 448x640 1 fire, 24.7ms
# Speed: 2.4ms preprocess, 24.7ms inference, 3.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs\segment\predict4
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.7955], device='cuda:0')
# data: tensor([[137.0033,  90.5222, 237.1073, 182.7808,   0.7955,   0.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (183, 275)
# shape: torch.Size([1, 6])
# xywh: tensor([[187.0553, 136.6515, 100.1040,  92.2586]], device='cuda:0')
# xywhn: tensor([[0.6802, 0.7467, 0.3640, 0.5041]], device='cuda:0')
# xyxy: tensor([[137.0033,  90.5222, 237.1073, 182.7808]], device='cuda:0')
# xyxyn: tensor([[0.4982, 0.4947, 0.8622, 0.9988]], device='cuda:0')

# %%
from PIL import Image
img = Image.open("runs/segment/train/results.png")
img.show()
